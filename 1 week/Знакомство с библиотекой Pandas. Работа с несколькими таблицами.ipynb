# %% [markdown]
# # Знакомство с библиотекой Pandas. Работа с несколькими таблицами

# %%
import pandas as pd

# %% [markdown]
# ### Типы объединения таблиц

# %% [markdown]
# <img src='https://www.shanelynn.ie/wp-content/uploads/2017/03/join-types-merge-names.jpg'>

# %% [markdown]
# #### Загрузим данные airbnb

# %%
calendar = pd.read_csv('boston-airbnb-open-data/calendar_sept.csv', index_col=0)
reviews = pd.read_csv('boston-airbnb-open-data/reviews_sample.csv', index_col=0)
listings = pd.read_csv('boston-airbnb-open-data/listings.csv', index_col=0)

# %%
calendar.head(2)
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN

# %%
reviews.head(2)
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...

# %%
listings.head(2)
# Out:
#            id                           listing_url       scrape_id  \
# 1553  1458081  https://www.airbnb.com/rooms/1458081  20160906204935
# 2950  8886703  https://www.airbnb.com/rooms/8886703  20160906204935
#
#      last_scraped                                               name  \
# 1553   2016-09-07  Beautiful 4BD/2BA Gem! Near airport, city, sub...
# 2950   2016-09-07                2Beautiful Philadelphia Style Home!
#
#                                                 summary  \
# 1553  You will love this condo! We are just a 7 minu...
# 2950  Our home is great for students and visitors to...
#
#                                                   space  \
# 1553  We are located in the Jeffries Point neighborh...
# 2950                                                NaN
#
#                                             description experiences_offered  \
# 1553  You will love this condo! We are just a 7 minu...                none
# 2950  Our home is great for students and visitors to...                none
#
#                                   neighborhood_overview  ...  \
# 1553  The neighborhood is great because it's accessi...  ...
# 2950                                                NaN  ...
#
#      review_scores_value requires_license license jurisdiction_names  \
# 1553                10.0                f     NaN                NaN
# 2950                 9.0                f     NaN                NaN
#
#      instant_bookable cancellation_policy require_guest_profile_picture  \
# 1553                t            moderate                             f
# 2950                f            moderate                             f
#
#      require_guest_phone_verification calculated_host_listings_count  \
# 1553                                f                              1
# 2950                                f                              2
#
#       reviews_per_month
# 1553               4.71
# 2950               1.11
#
# [2 rows x 95 columns]

# %% [markdown]
# #### Inner join

# %%
pd.merge(listings, reviews, left_on = ['id'], right_on=['listing_id']).head()
# Out:
# Empty DataFrame
# Columns: [id_x, listing_url, scrape_id, last_scraped, name, summary, space, description, experiences_offered, neighborhood_overview, notes, transit, access, interaction, house_rules, thumbnail_url, medium_url, picture_url, xl_picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, street, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, city, state, zipcode, market, smart_location, country_code, country, latitude, longitude, is_location_exact, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, minimum_nights, maximum_nights, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, requires_license, license, jurisdiction_names, instant_bookable, cancellation_policy, require_guest_profile_picture, require_guest_phone_verification, calculated_host_listings_count, reviews_per_month, listing_id, id_y, date, reviewer_id, reviewer_name, ...]
# Index: []
#
# [0 rows x 101 columns]

# %%
pd.merge(calendar, reviews, on=['listing_id']).head()
# Out:
#    listing_id      date_x available   price       id      date_y  reviewer_id  \
# 0     1178162  2017-09-05         t  $95.00  4724140  2013-05-21      4298113
# 1     1178162  2017-09-05         t  $95.00  4869189  2013-05-29      6452964
# 2     1178162  2017-09-05         t  $95.00  5003196  2013-06-06      6449554
# 3     1178162  2017-09-05         t  $95.00  5150351  2013-06-15      2215611
# 4     1178162  2017-09-05         t  $95.00  5171140  2013-06-16      6848427
#
#   reviewer_name                                           comments
# 0       Olivier  My stay at islam's place was really cool! Good...
# 1     Charlotte  Great location for both airport and city - gre...
# 2     Sebastian  We really enjoyed our stay at Islams house. Fr...
# 3        Marine  The room was nice and clean and so were the co...
# 4        Andrew  Great location. Just 5 mins walk from the Airp...

# %% [markdown]
# ###   Пример left merge

# %%
result = pd.merge(calendar, reviews, on=['listing_id'], how='left')

# %%
result.head()
# Out:
#    listing_id      date_x available price  id date_y  reviewer_id  \
# 0    12147973  2017-09-05         f   NaN NaN    NaN          NaN
# 1    12147973  2017-09-04         f   NaN NaN    NaN          NaN
# 2    12147973  2017-09-03         f   NaN NaN    NaN          NaN
# 3    12147973  2017-09-02         f   NaN NaN    NaN          NaN
# 4    12147973  2017-09-01         f   NaN NaN    NaN          NaN
#
#   reviewer_name comments
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN

# %% [markdown]
# ###  Пример  right merge

# %%
result = pd.merge(calendar, reviews, on=['listing_id'], how='right')

# %%
result.head()
# Out:
#    listing_id      date_x available   price       id      date_y  reviewer_id  \
# 0     1178162  2017-09-05         t  $95.00  4724140  2013-05-21      4298113
# 1     1178162  2017-09-04         t  $95.00  4724140  2013-05-21      4298113
# 2     1178162  2017-09-03         t  $95.00  4724140  2013-05-21      4298113
# 3     1178162  2017-09-02         t  $95.00  4724140  2013-05-21      4298113
# 4     1178162  2017-09-01         t  $95.00  4724140  2013-05-21      4298113
#
#   reviewer_name                                           comments
# 0       Olivier  My stay at islam's place was really cool! Good...
# 1       Olivier  My stay at islam's place was really cool! Good...
# 2       Olivier  My stay at islam's place was really cool! Good...
# 3       Olivier  My stay at islam's place was really cool! Good...
# 4       Olivier  My stay at islam's place was really cool! Good...

# %% [markdown]
# Можно добавить аргумент indicator=True, чтобы увидеть, какие строки из какой таблицы объединились

# %%
result = pd.merge(calendar, reviews[:100], on=['listing_id'], how='left',indicator=True)

# %%
result.head()
# Out:
#    listing_id      date_x available price  id date_y  reviewer_id  \
# 0    12147973  2017-09-05         f   NaN NaN    NaN          NaN
# 1    12147973  2017-09-04         f   NaN NaN    NaN          NaN
# 2    12147973  2017-09-03         f   NaN NaN    NaN          NaN
# 3    12147973  2017-09-02         f   NaN NaN    NaN          NaN
# 4    12147973  2017-09-01         f   NaN NaN    NaN          NaN
#
#   reviewer_name comments     _merge
# 0           NaN      NaN  left_only
# 1           NaN      NaN  left_only
# 2           NaN      NaN  left_only
# 3           NaN      NaN  left_only
# 4           NaN      NaN  left_only

# %% [markdown]
# Пример join - нужные столбцы превращаются в индекс, а потом происходит объединение

# %%
calendar.set_index('listing_id', inplace=True)

# %%
reviews.set_index('listing_id', inplace=True)

# %%
calendar.join(reviews, lsuffix='listing_id', 
              rsuffix='listing_id').head()
# Out:
#            datelisting_id available   price  id datelisting_id  reviewer_id  \
# listing_id
# 3353           2017-09-05         t  $36.00 NaN            NaN          NaN
# 3353           2017-09-04         t  $36.00 NaN            NaN          NaN
# 3353           2017-09-03         t  $36.00 NaN            NaN          NaN
# 3353           2017-09-02         t  $36.00 NaN            NaN          NaN
# 3353           2017-09-01         t  $36.00 NaN            NaN          NaN
#
#            reviewer_name comments
# listing_id
# 3353                 NaN      NaN
# 3353                 NaN      NaN
# 3353                 NaN      NaN
# 3353                 NaN      NaN
# 3353                 NaN      NaN
