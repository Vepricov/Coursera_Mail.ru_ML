# %% [markdown]
# # Знакомство с библиотекой Pandas. Dataframe

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Размер датасета, типы данных и названия столбцов

# %%
df = pd.read_csv('bike_sharing_demand.csv', sep = ',')

# %%
df.head(3)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32

# %%
df.tail(3)
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %%
df.shape
# Out:
# (10886, 12)

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
df.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
df[['season', 'holiday', 'workingday']].head()
# Out:
#    season  holiday  workingday
# 0       1        0           0
# 1       1        0           0
# 2       1        0           0
# 3       1        0           0
# 4       1        0           0

# %% [markdown]
# ### 2. loc/iloc - обращение к элементам датафрейма

# %%
df.iloc[-1]
# Out:
# datetime      2012-12-19 23:00:00
# season                          4
# holiday                         0
# workingday                      1
# weather                         1
# temp                        13.12
# atemp                      16.665
# humidity                       66
# windspeed                  8.9981
# casual                          4
# registered                     84
# count                          88
# Name: 10885, dtype: object

# %%
df.iloc[-1, 5]
# Out:
# 13.12

# %%
df.loc[1, ['temp']]
# Out:
# temp    9.02
# Name: 1, dtype: object

# %%
df.iloc[0:6, 0:4]
# Out:
#               datetime  season  holiday  workingday
# 0  2011-01-01 00:00:00       1        0           0
# 1  2011-01-01 01:00:00       1        0           0
# 2  2011-01-01 02:00:00       1        0           0
# 3  2011-01-01 03:00:00       1        0           0
# 4  2011-01-01 04:00:00       1        0           0
# 5  2011-01-01 05:00:00       1        0           0

# %%
df.loc[0:6, 'datetime':'weather']
# Out:
#               datetime  season  holiday  workingday  weather
# 0  2011-01-01 00:00:00       1        0           0        1
# 1  2011-01-01 01:00:00       1        0           0        1
# 2  2011-01-01 02:00:00       1        0           0        1
# 3  2011-01-01 03:00:00       1        0           0        1
# 4  2011-01-01 04:00:00       1        0           0        1
# 5  2011-01-01 05:00:00       1        0           0        2
# 6  2011-01-01 06:00:00       1        0           0        1

# %% [markdown]
# ### 3. Фильтрация

# %%
df[df['weather'] > 1].head()
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 5   2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 13  2011-01-01 13:00:00       1        0           0        2  18.86  22.725
# 14  2011-01-01 14:00:00       1        0           0        2  18.86  22.725
# 15  2011-01-01 15:00:00       1        0           0        2  18.04  21.970
# 16  2011-01-01 16:00:00       1        0           0        2  17.22  21.210
#
#     humidity  windspeed  casual  registered  count
# 5         75     6.0032       0           1      1
# 13        72    19.9995      47          47     94
# 14        72    19.0012      35          71    106
# 15        77    19.9995      40          70    110
# 16        82    19.9995      41          52     93

# %%
df[(df['weather'] > 1) & (df['atemp'] > 20)].head()
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 13  2011-01-01 13:00:00       1        0           0        2  18.86  22.725
# 14  2011-01-01 14:00:00       1        0           0        2  18.86  22.725
# 15  2011-01-01 15:00:00       1        0           0        2  18.04  21.970
# 16  2011-01-01 16:00:00       1        0           0        2  17.22  21.210
# 17  2011-01-01 17:00:00       1        0           0        2  18.04  21.970
#
#     humidity  windspeed  casual  registered  count
# 13        72    19.9995      47          47     94
# 14        72    19.0012      35          71    106
# 15        77    19.9995      40          70    110
# 16        82    19.9995      41          52     93
# 17        82    19.0012      15          52     67

# %% [markdown]
# ### 4. Статистика по датафрейму

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df.describe(include = [np.object])
# Out:
#                    datetime
# count                 10886
# unique                10886
# top     2011-07-15 18:00:00
# freq                      1

# %% [markdown]
# Статистика по значениям внутри столбца

# %%
df['season'].value_counts(normalize = True)
# Out:
# 4    0.251148
# 2    0.251056
# 3    0.251056
# 1    0.246739
# Name: season, dtype: float64

# %%
df['season'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
df.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
#
#             humidity  windspeed    casual  registered     count
# ...

# %% [markdown]
# А также можно сделать семпл данных, предварительно задав какой процент от датасета пойдет в семпл

# %%
df.sample(frac = 0.1)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 3906  2011-09-13 19:00:00       3        0           1        1  27.88
# 9945  2012-10-18 18:00:00       4        0           1        2  22.96
# 3006  2011-07-14 04:00:00       3        0           1        1  25.42
# 3868  2011-09-12 05:00:00       3        0           1        1  22.96
# 3819  2011-09-10 03:00:00       3        0           0        1  23.78
# ...                   ...     ...      ...         ...      ...    ...
# 7640  2012-05-17 17:00:00       2        0           1        1  27.06
# 8339  2012-07-08 20:00:00       3        0           0        1  31.16
# 5900  2012-02-02 01:00:00       1        0           1        2  18.86
# 4918  2011-11-18 00:00:00       4        0           1        1  10.66
# 6328  2012-02-19 22:00:00       1        0           0        3   9.84
#
#        atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# ### 5. Запись в csv

# %%
df.to_csv('path_to_file.csv')
